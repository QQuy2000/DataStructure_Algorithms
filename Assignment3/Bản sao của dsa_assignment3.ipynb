# %% [markdown]
# # 1. Preparation for grading Assignment1@DSA
# ## 1.1. General steps:
# 1. Specify **FileID**
# 2. Specify **StudentID**
# 3. Sepcify **TestID** (See Section 2.)
#
# ## 1.2. Prepare your code and zip-file
# In this colab, we assume that your student id is **19500XX** and use that id in the tutorial. You HAVE TO **REPLACE** **19500XX** with your id.
#
# Follows the intructions given below to upload for code and do grading by yourself.
# * Create a zip file with name: **19500XX.zip** (again, replace **19500XX** with your student id)
# * The zip-file must contain folders and files as shown in the figure below:
#   * Top director must be your student id, e.g. **19500XX**.
#   * All sub-folders and files are organized as the given by the instructor.
#     * Your files for Assignment1 are in **19500XX/dsacpp/include/list** (actually, we use only the files in this folder)
#
#
# **Organization of your code:**
#
# <a href="https://ibb.co/Mgf13cS"><img src="https://i.ibb.co/4F2S58t/folder.png" alt="folder" border="0"></a>
#
# ## 1.3. Obtain file's id
# 1. Upload your zip file to Google Drive
# 2. Share it publicly (i.e. anyone with link)
# 3. Get link:
#
# * Assume the link is: https://drive.google.com/file/d/1fd1RkzSjpLbVQBIIhUoOYV9vXce9ZAc2/view?usp=sharing
# * Then FileID: **1fd1RkzSjpLbVQBIIhUoOYV9vXce9ZAc2**
#
# 1.4 Run the following cell
# 1. Specify file's id mentioned above to **FILEID**
# 2. Specify your student id to **STUDENT_ID**
# 3. **RUN THE FOLLOWING CELLS**

# %%
# %%shell
# ################################################################################
# # Preparing DSA's framework (student version)
# # Steps:
# # (1) Assign FILEID with the id of the file containing your dsa-framework
# #       * In your Google Drive: share your dsa-framework with mode "anyone with link (Bat ky ai co duong link)"
# #       * Example:
# #         IF URL: https://drive.google.com/file/d/1fd1RkzSjpLbVQBIIhUoOYV9vXce9ZAc2/view?usp=sharing
# #         THEN FILEID = 1fd1RkzSjpLbVQBIIhUoOYV9vXce9ZAc2
# #
# # (2) Assign STUDENT_ID with your student's id
# # (2) Run this cell
# ################################################################################
# FILEID="1hv8AK5emFmSrdrZdruxj8QG-DcQUBoyB"
# STUDENT_ID="1852704" #REPLACE "dsastudents" with your student's id
#
# ########################## DO NOT CHANGE THE FOLLOWING #########################
# cd /content
# rm -f -r "$STUDENT_ID" "$STUDENT_ID".zip
# gdown -q --id $FILEID --output "$STUDENT_ID".zip
# unzip -q "$STUDENT_ID".zip
# rm -f settings.txt
# printf "STUDENT_ID=$STUDENT_ID\n" >> settings.txt
# printf "WORKINGSPACE=/content/$STUDENT_ID\n" >> settings.txt
# echo "Preparation: Done"
# Out:
# replace __MACOSX/1852704/._.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# Preparation: Done

# %%
################################################################################
# Change the current directory
# Steps:
# (1) REPLACE "dsastudents" with your student's id
# (2) RUN this cell
################################################################################

# !echo "Current directory:"
# %cd /content/1852704 
# %pwd

# !echo ""
# !echo "Current directory's content:"
# %ls -l
# Out:
# Current directory:
# /content/1852704
#
# Current directory's content:
# total 660
# drwxrwxr-x 3 root root   4096 Jun 16 10:05 build/
# drwxrwxr-x 3 root root   4096 Jun 16 10:05 dist/
# drwxr-xr-x 3 root root   4096 Jun  8 11:26 doctest/
# drwxr-xr-x 4 root root   4096 Jun 17 09:50 dsacpp/
# -rwxr-xr-x 1 root root 624256 Jul 11 06:37 dsa_main_test*
# -rwxr-xr-- 1 root root    760 Jun 14 03:08 dsa_main_test.sh*
# drwxrwxr-x 4 root root   4096 Jun 12 15:23 examples/
# -rwxr-xr-- 1 root root   1285 Jun 14 03:09 examples.sh*
# -rwxr-xr-x 1 root root   4248 Jun 12 15:41 main*
# -rw-rw-r-- 1 root root    378 Jun 12 13:27 main.cpp
# -rw-rw-r-- 1 root root   3482 Jun 12 13:27 Makefile
# drwxrwxr-x 3 root root   4096 Jun 12 13:27 nbproject/

# %% [markdown]
# # 2. Do grading
# ## 2.1 Download TestCases
# Copy the TestID given by your instructor on BKeL system and assign it to TESTID given in the following cell.
#
# ## 2.2 Do grading
# * Just **run** the following cells after assigning the testID.
#
#
# **IMPORTANT DEADLINE**:
# * TestID given will posted to BKeL on **June 27, 2021; from 15h**
# * You have to **run** the following cells to do grading by yourself, must before **June 27, 2021; 21H**
#
#
# If you passed all the tests, you can see the following picture.
#
# <a href="https://ibb.co/jf9kBhn"><img src="https://i.ibb.co/V90YrVf/testresult.png" alt="testresult" border="0"></a>

# %%
# %%shell
#
# TESTID="1bIgU1NDuLY4ieFVJJNuo7U6UwopJVLkO"
# cd /content/
# source settings.txt
# rm -f assigment3.zip
# gdown -q --id $TESTID --output assignment3.zip
# unzip -q assignment3.zip
# cp -rf ./assignment3/* ./$STUDENT_ID
# rm -rf /content/assignment3
# rm -f assignment3.zip

# %%
# %%shell
#
# sh dsa_main_test.sh
# Out:
# ###################################################################################
# ##############              GRADING ASSINMENT3 OF DSA               ###############
# ##############             (unittest for C++: doctest)              ###############
# ###################################################################################
# [1] removing previous output ...
# [2] building DSACPP, please wait ...
# ###################################################################################
# [3] running the test ...
#
#
# [doctest] doctest version is "2.4.0"
# [doctest] run with "--help" for options
# ...
# [doctest] test cases:     30 |     30 passed |      0 failed |      0 skipped
# [doctest] assertions: 163367 | 163367 passed |      0 failed |
# [doctest] Status: SUCCESS!

# %% [markdown]
# #PART 2

# %%
# %%writefile sorttime.cpp
#
# #include <iostream>
# #include <fstream>
# #include <chrono>
# using namespace std;
# using namespace std::chrono;
#
# #include "list/SLinkedList.h"
# #include "list/DLinkedList.h"
# #include "list/XArrayList.h"
# #include "sorting/ISort.h"
# #include "heap/Heap.h"
# #include "sorting/BubbleSort.h"
# #include "sorting/DLinkedListSE.h"
# #include "sorting/SLinkedListSE.h"
# #include "sorting/XArrayListSE.h"
# #include "sorting/HeapSort.h"
# #include "sorting/QuickSort.h"
# #include "sorting/ShellSort.h"
# #include "sorting/StraightInsertionSort.h"
# #include "sorting/StraightSelectionSort.h"
# #include "util/ArrayLib.h"
# #include <algorithm>
#
# /* Ordered_list:  */
# double ISort_Ordered(ISort<int>* pList, int size, int nexec){
#     int* genIntArr = new int[size];
#     for(int i=0; i < size; i++){
#         genIntArr[i] = i;
#     }
#     double total = 0;
#     for (int j = 0; j < nexec; j++){
#       auto start = high_resolution_clock::now();
#       pList->sort(genIntArr, size, &SortSimpleOrder<int>::compare4Ascending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#     }
#     delete[] genIntArr;
#     return (total/nexec);
# }
# double SLL_ordered(SLinkedListSE<int>* pList, int size, int nexec){
#   pList->clear();
#   for(int i=0; i < size; i++){
#     pList->add(i);
#   }
#   double total = 0;
#   for (int j = 0; j < nexec; j++){
#       auto start = high_resolution_clock::now();
#       pList->sort(&SortSimpleOrder<int>::compare4Ascending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#     }
#     pList->clear();
#     return (total/nexec);
# }
#
# double DLL_ordered(DLinkedListSE<int>* pList, int size, int nexec){
#   pList->clear();
#   for(int i=0; i < size; i++){
#     pList->add(i);
#   }
#   double total = 0;
#   for (int j = 0; j < nexec; j++){
#       auto start = high_resolution_clock::now();
#       pList->sort(&SortSimpleOrder<int>::compare4Ascending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#     }
#     pList->clear();
#     return (total/nexec);
# }
#
# double XArr_ordered(XArrayListSE<int>* pList, int size, int nexec){
#   pList->clear();
#   for(int i=0; i < size; i++){
#     pList->add(i);
#   }
#    double total = 0;
#   for (int j = 0; j < nexec; j++){
#       auto start = high_resolution_clock::now();
#       pList->sort(&SortSimpleOrder<int>::compare4Ascending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#     }
#     pList->clear();
#     return (total/nexec);
# }
#
#
# /* REVERSE ORDER*/
# double ISort_Ordered_reverse(ISort<int>* pList, int size, int nexec){
#     int* genIntArr = new int[size];
#     double total = 0;
#     for (int j = 0; j < nexec; j++){
#       for(int i=0; i < size; i++){
#         genIntArr[i] = i;
#       }
#       auto start = high_resolution_clock::now();
#       pList->sort(genIntArr, size, &SortSimpleOrder<int>::compare4Desending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#     }
#     delete[] genIntArr;
#     return (total/nexec);
# }
# double SLL_ordered_reverse(SLinkedListSE<int>* pList, int size, int nexec){
#   double total = 0;
#   for (int j = 0; j < nexec; j++){
#       pList->clear();
#       for(int i=0; i < size; i++){
#         pList->add(i);
#       }
#       auto start = high_resolution_clock::now();
#       pList->sort(&SortSimpleOrder<int>::compare4Desending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#       pList->clear();
#     }
#     pList->clear();
#     return (total/nexec);
# }
#
# double DLL_ordered_reverse(DLinkedListSE<int>* pList, int size, int nexec){
#   double total = 0;
#   for (int j = 0; j < nexec; j++){
#       pList->clear();
#       for(int i=0; i < size; i++){
#         pList->add(i);
#       }
#       auto start = high_resolution_clock::now();
#       pList->sort(&SortSimpleOrder<int>::compare4Desending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#       pList->clear();
#     }
#     pList->clear();
#     return (total/nexec);
# }
#
# double XArr_ordered_reverse(XArrayListSE<int>* pList, int size, int nexec){
#   double total = 0;
#   for (int j = 0; j < nexec; j++){
#       pList->clear();
#       for(int i=0; i < size; i++){
#         pList->add(i);
#       }
#       auto start = high_resolution_clock::now();
#       pList->sort(&SortSimpleOrder<int>::compare4Desending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#       pList->clear();
#     }
#     pList->clear();
#     return (total/nexec);
# }
#
# /* RANDOM ORDER*/
# double ISort_Ordered_random(ISort<int>* pList, int size, int nexec){
#     int* genIntArr = new int[size];
#     int* k = genIntArray(size, 0, size+100);
#     double total = 0;
#     for (int j = 0; j < nexec; j++){
#       for(int i=0; i < size; i++){
#         genIntArr[i] = k[i];
#       }
#       auto start = high_resolution_clock::now();
#       pList->sort(genIntArr, size, &SortSimpleOrder<int>::compare4Desending);
#       auto stop = high_resolution_clock::now();
#       duration<double> time_span = duration_cast<microseconds> (stop - start);
#       total += time_span.count();
#     }
#     delete[] k;
#     delete[] genIntArr;
#     return (total/nexec);
# }
# double SLL_ordered_random(SLinkedListSE<int>* pList, int size, int nexec){
#   double total = 0;
#   int* k = genIntArray(size, 0, size+100);
#   for (int j = 0; j < nexec; j++){
#     pList->clear();
#     for(int i=0; i < size; i++){
#           pList->add(k[i]);
#     }
#     auto start = high_resolution_clock::now();
#     pList->sort(&SortSimpleOrder<int>::compare4Desending);
#     auto stop = high_resolution_clock::now();
#     duration<double> time_span = duration_cast<microseconds> (stop - start);
#     total += time_span.count();
#     pList->clear();
#   }
#   pList->clear();
#   return (total/(nexec));
# }
#
# double DLL_ordered_random(DLinkedListSE<int>* pList, int size, int nexec){
#   double total = 0;
#   int* k = genIntArray(size, 0, size+100);
#   for (int j = 0; j < nexec; j++){
#     pList->clear();
#     for(int i=0; i < size; i++){
#           pList->add(k[i]);
#     }
#     auto start = high_resolution_clock::now();
#     pList->sort(&SortSimpleOrder<int>::compare4Desending);
#     auto stop = high_resolution_clock::now();
#     duration<double> time_span = duration_cast<microseconds> (stop - start);
#     total += time_span.count();
#     pList->clear();
#   }
#   pList->clear();
#   return (total/(nexec));
# }
#
# double XArr_ordered_random(XArrayListSE<int>* pList, int size, int nexec){
#   double total = 0;
#   int* k = genIntArray(size, 0, size+100);
#   for (int j = 0; j < nexec; j++){
#     pList->clear();
#     for(int i=0; i < size; i++){
#           pList->add(k[i]);
#     }
#     auto start = high_resolution_clock::now();
#     pList->sort(&SortSimpleOrder<int>::compare4Desending);
#     auto stop = high_resolution_clock::now();
#     duration<double> time_span = duration_cast<microseconds> (stop - start);
#     total += time_span.count();
#     pList->clear();
#   }
#   pList->clear();
#   return (total/(nexec));
# }
#
#  void sort(ISort<int>* pBubble, ISort<int>* pShell, ISort<int>* pQuick, ISort<int>* pHeap, ISort<int>* pSelect, ISort<int>* pInsert,
#            SLinkedListSE<int>* pSLL, DLinkedListSE<int>* pDLL, XArrayListSE<int>* pXArr, string csvfile, int* ptr_size, int nsizes, int nexec=10, int ntries=10){
#       std::ofstream csvstream;
#       csvstream.open (csvfile, std::ofstream::out | std::ofstream::app);
#       csvstream   << "n" << ","
#                   << "Bubble(ms)" << ","
#                   << "Shell(ms)" << ","
#                   << "Quick(ms)" << ","
#                   << "Heap(ms)" << ","
#                   << "Select(ms)" << ","
#                   << "Insert(ms)" << ","
#                   << "SLinkedList_Merge(ms)" << ","
#                   << "DLinkedList_Merge(ms)" << ","
#                   << "XArrayList_Merge(ms)" << endl;
#       cout    <<"n"<<"\t ->"
#               << fixed<<setw(18) << setprecision(8) << "Bubble(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Shell(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Quick(ms)" << ","
#               << fixed<<setw(18) << setprecision(8) << "Heap(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Select(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Insert(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "SLinkedList_Merge(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "DLinkedList_Merge(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "XArrayList_Merge(ms)"  << endl;
#
#       for(int i=0; i<nsizes; i++){
#         double Bubble_sort = ISort_Ordered(pBubble, ptr_size[i], nexec);
#         double Shell_sort = ISort_Ordered(pShell, ptr_size[i], nexec);
#         double Quick_sort = ISort_Ordered(pQuick, ptr_size[i], nexec);
#         double Heap_sort = ISort_Ordered(pHeap, ptr_size[i], nexec);
#         double Select_sort = ISort_Ordered(pSelect, ptr_size[i], nexec);
#         double Insert_sort = ISort_Ordered(pInsert, ptr_size[i], nexec);
#         double SLL_sort =  SLL_ordered(pSLL , ptr_size[i], nexec);
#         double DLL_sort =  DLL_ordered(pDLL , ptr_size[i], nexec);
#         double XArr_sort = XArr_ordered(pXArr , ptr_size[i], nexec);
#         if(i%10 == 0)
#             cout    <<ptr_size[i]<<"\t ->"
#                     << fixed<<setw(18) << setprecision(8) << Bubble_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Shell_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Quick_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Heap_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Select_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Insert_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << SLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << DLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << XArr_sort << endl;
#
#         csvstream   << ptr_size[i] <<", "
#                     << fixed<<setw(18) << setprecision(8) << Bubble_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Shell_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Quick_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Heap_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Select_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Insert_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << SLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << DLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << XArr_sort << endl;
#     }
#     cout << "Done" << endl;
#
#     csvstream.close();
#
# }
#
# void sort_reverse(ISort<int>* pBubble, ISort<int>* pShell, ISort<int>* pQuick, ISort<int>* pHeap, ISort<int>* pSelect, ISort<int>* pInsert,
#            SLinkedListSE<int>* pSLL, DLinkedListSE<int>* pDLL, XArrayListSE<int>* pXArr, string csvfile, int* ptr_size, int nsizes, int nexec=10, int ntries=10){
#       std::ofstream csvstream;
#       csvstream.open (csvfile, std::ofstream::out | std::ofstream::app);
#       csvstream   << "n" << ","
#                   << "Bubble(ms)" << ","
#                   << "Shell(ms)" << ","
#                   << "Quick(ms)" << ","
#                   << "Heap(ms)" << ","
#                   << "Select(ms)" << ","
#                   << "Insert(ms)" << ","
#                   << "SLinkedList_Merge(ms)" << ","
#                   << "DLinkedList_Merge(ms)" << ","
#                   << "XArrayList_Merge(ms)" << endl;
#       cout    <<"n"<<"\t ->"
#               << fixed<<setw(18) << setprecision(8) << "Bubble(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Shell(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Quick(ms)" << ","
#               << fixed<<setw(18) << setprecision(8) << "Heap(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Select(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Insert(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "SLinkedList_Merge(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "DLinkedList_Merge(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "XArrayList_Merge(ms)"  << endl;
#
#       for(int i=0; i<nsizes; i++){
#         double Bubble_sort = ISort_Ordered_reverse(pBubble, ptr_size[i], nexec);
#         double Shell_sort = ISort_Ordered_reverse(pShell, ptr_size[i], nexec);
#         double Quick_sort = ISort_Ordered_reverse(pQuick, ptr_size[i], nexec);
#         double Heap_sort = ISort_Ordered_reverse(pHeap, ptr_size[i], nexec);
#         double Select_sort = ISort_Ordered_reverse(pSelect, ptr_size[i], nexec);
#         double Insert_sort = ISort_Ordered_reverse(pInsert, ptr_size[i], nexec);
#         double SLL_sort =  SLL_ordered_reverse(pSLL , ptr_size[i], nexec);
#         double DLL_sort =  DLL_ordered_reverse(pDLL , ptr_size[i], nexec);
#         double XArr_sort = XArr_ordered_reverse(pXArr , ptr_size[i], nexec);
#         if(i%10 == 0)
#             cout    <<ptr_size[i]<<"\t ->"
#                     << fixed<<setw(18) << setprecision(8) << Bubble_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Shell_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Quick_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Heap_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Select_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Insert_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << SLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << DLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << XArr_sort << endl;
#
#         csvstream   << ptr_size[i] <<", "
#                     << fixed<<setw(18) << setprecision(8) << Bubble_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Shell_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Quick_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Heap_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Select_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Insert_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << SLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << DLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << XArr_sort << endl;
#     }
#     cout << "Done" << endl;
#
#     csvstream.close();
#
# }
# void sort_random(ISort<int>* pBubble, ISort<int>* pShell, ISort<int>* pQuick, ISort<int>* pHeap, ISort<int>* pSelect, ISort<int>* pInsert,
#            SLinkedListSE<int>* pSLL, DLinkedListSE<int>* pDLL, XArrayListSE<int>* pXArr, string csvfile, int* ptr_size, int nsizes, int nexec=10, int ntries=10){
#       std::ofstream csvstream;
#       csvstream.open (csvfile, std::ofstream::out | std::ofstream::app);
#       csvstream   << "n" << ","
#                   << "Bubble(ms)" << ","
#                   << "Shell(ms)" << ","
#                   << "Quick(ms)" << ","
#                   << "Heap(ms)" << ","
#                   << "Select(ms)" << ","
#                   << "Insert(ms)" << ","
#                   << "SLinkedList_Merge(ms)" << ","
#                   << "DLinkedList_Merge(ms)" << ","
#                   << "XArrayList_Merge(ms)" << endl;
#       cout    <<"n"<<"\t ->"
#               << fixed<<setw(18) << setprecision(8) << "Bubble(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Shell(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Quick(ms)" << ","
#               << fixed<<setw(18) << setprecision(8) << "Heap(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Select(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "Insert(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "SLinkedList_Merge(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "DLinkedList_Merge(ms)" << ", "
#               << fixed<<setw(18) << setprecision(8) << "XArrayList_Merge(ms)"  << endl;
#
#       for(int i=0; i<nsizes; i++){
#         double Bubble_sort = ISort_Ordered_random(pBubble, ptr_size[i], nexec);
#         double Shell_sort = ISort_Ordered_random(pShell, ptr_size[i], nexec);
#         double Quick_sort = ISort_Ordered_random(pQuick, ptr_size[i], nexec);
#         double Heap_sort = ISort_Ordered_random(pHeap, ptr_size[i], nexec);
#         double Select_sort = ISort_Ordered_random(pSelect, ptr_size[i], nexec);
#         double Insert_sort = ISort_Ordered_random(pInsert, ptr_size[i], nexec);
#         double SLL_sort =  SLL_ordered_random(pSLL , ptr_size[i], nexec);
#         double DLL_sort =  DLL_ordered_random(pDLL , ptr_size[i], nexec);
#         double XArr_sort = XArr_ordered_random(pXArr , ptr_size[i], nexec);
#         if(i%10 == 0)
#             cout    <<ptr_size[i]<<"\t ->"
#                     << fixed<<setw(18) << setprecision(8) << Bubble_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Shell_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Quick_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Heap_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Select_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Insert_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << SLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << DLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << XArr_sort << endl;
#
#         csvstream   << ptr_size[i] <<", "
#                     << fixed<<setw(18) << setprecision(8) << Bubble_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Shell_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Quick_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Heap_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Select_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << Insert_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << SLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << DLL_sort << ", "
#                     << fixed<<setw(18) << setprecision(8) << XArr_sort << endl;
#     }
#     cout << "Done" << endl;
#
#     csvstream.close();
#
# }
# int get_int(char** begin, char** end, const string& option, int _default){
#     char** ptr = std::find(begin, end, option);
#     if (ptr != end && ++ptr != end) return stoi(*ptr);
#     else return _default;
# }
#
# string get_string(char** begin, char** end, const string& option, string _default){
#     char** ptr = std::find(begin, end, option);
#     if (ptr != end && ++ptr != end) return string(*ptr);
#     else return _default;
# }
# bool option_exist(char** begin, char** end, const string& option){
#     return std::find(begin, end, option) != end;
# }
#
# int main(int argc, char** argv){
#     if(option_exist(argv, argv+argc, "-h")){
#         cout << "Show help" << endl;
#         return 0;
#     }
#     ///////////////////////////////////////////////////////////////////////////
#     int nsizes, nexec, max_length, ntries;
#     BubbleSort<int> bubble;
#     int num_seg[] = {1,3,7,9,11,13,15,17,19,21};
#     ShellSort<int> shell(num_seg,10);
#     QuickSort<int> quick;
#     HeapSort<int> heap;
#     StraightSelectionSort<int> select;
#     StraightInsertionSort<int> insert;
#     SLinkedListSE<int> SLL;
#     DLinkedListSE<int> DLL;
#     XArrayListSE<int> XArr;
#
#
#     nsizes = get_int(argv, argv+argc, "-nsizes", 50);
#     nexec = get_int(argv, argv+argc, "-nexec", 20);
#     max_length = get_int(argv, argv+argc, "-max_length", 1000);
#     ntries = get_int(argv, argv+argc, "-ntries", 10);
#     int* ptr_sizes = genIntArray(nsizes, 1, max_length);
#     if(option_exist(argv, argv+argc, "-o")){
#         cout << endl;
#         cout << "Sorting methods(Input: Ascending list => Output: Ascending list) : Time measurement" << endl;
#         cout << string(80, '-') << endl;
#         string filename = get_string(argv, argv+argc, "-o", "");
#         sort(&bubble, &shell, &quick, &heap, &select, &insert, &SLL, &DLL, &XArr, filename, ptr_sizes, nsizes, nexec, ntries);
#     }
#     if(option_exist(argv, argv+argc, "-or")){
#         cout << endl;
#         cout << "Sorting methods(Input: Ascending list => Output: Desending list) : Time measurement" << endl;
#         cout << string(80, '-') << endl;
#         string filename = get_string(argv, argv+argc, "-or", "");
#         sort_reverse(&bubble, &shell, &quick, &heap, &select, &insert, &SLL, &DLL, &XArr, filename, ptr_sizes, nsizes, nexec, ntries);
#     }
#     if(option_exist(argv, argv+argc, "-r")){
#         cout << endl;
#         cout << "Sorting methods(Input: Random list => Output: Desending list) : Time measurement" << endl;
#         cout << string(80, '-') << endl;
#         string filename = get_string(argv, argv+argc, "-r", "");
#         sort_random(&bubble, &shell, &quick, &heap, &select, &insert, &SLL, &DLL, &XArr, filename, ptr_sizes, nsizes, nexec, ntries);
#     }
# }
# Out:
# Overwriting sorttime.cpp

# %%
# %%shell
#
# rm -f sorttime
# INCLUDE=./dsacpp/include
# SOURCE=./dsacpp/src
# g++ -std=c++11 sorttime.cpp $SOURCE/geom/*.cpp -I $INCLUDE -o sorttime
# rm -f sortOrdered.csv sortOrderedReverse.csv sortRandom.csv
# ./sorttime -o sortOrdered.csv -nsizes 100 -ntries 10 -nexec 20 -max_length 5000
# ./sorttime -or sortOrderedReverse.csv -nsizes 100 -ntries 10 -nexec 20 -max_length 5000
# ./sorttime -r sortRandom.csv -nsizes 100 -ntries 10 -nexec 20 -max_length 5000
# Out:
# Sorting methods(Input: Ascending list => Output: Ascending list) : Time measurement
# --------------------------------------------------------------------------------
# n	 ->        Bubble(ms),          Shell(ms),          Quick(ms),          Heap(ms),         Select(ms),         Insert(ms), SLinkedList_Merge(ms), DLinkedList_Merge(ms), XArrayList_Merge(ms)
# 4446	 ->        0.00002685,         0.00038275,         0.00054190,         0.00201560,         0.05538370,         0.00003425,         0.00058910,         0.00066845,         0.00055620
# 2403	 ->        0.00001365,         0.00020025,         0.00027170,         0.00103195,         0.01592460,         0.00001805,         0.00029620,         0.00034200,         0.00026970
# 475	 ->        0.00000205,         0.00004045,         0.00004345,         0.00015370,         0.00062620,         0.00000320,         0.00005270,         0.00005590,         0.00004415
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,1], c='k', marker='*', alpha=0.9, label='Bubble(ms)')
plt.scatter(Order_list[:, 0],  Order_list[:,2], c='r', marker='d', alpha=0.9, label='Shell(ms)')
plt.scatter(Order_list[:, 0],  Order_list[:,3], c='g', marker='s', alpha=0.9, label='Quick(ms)')
plt.scatter(Order_list[:, 0],  Order_list[:,4], c='b', marker='o', alpha=0.9, label='Heap(ms)')
plt.scatter(Order_list[:, 0],  Order_list[:,5], c='m', marker='<', alpha=0.9, label='Select(ms)')
plt.scatter(Order_list[:, 0],  Order_list[:,6], c='y', marker='v', alpha=0.9, label='Insert(ms)')
plt.scatter(Order_list[:, 0],  Order_list[:,7], c='c', marker='>', alpha=0.9, label=' SLinkedList_Merge(ms)')
plt.scatter(Order_list[:, 0],  Order_list[:,8], c='navy', marker='^', alpha=0.9, label='DLinkedList_Merge(ms)')
plt.scatter(Order_list[:, 0],  Order_list[:,9], c='deeppink', marker='+', alpha=0.9, label='XArrayList_Merge(ms)')

plt.legend()
plt.title('Computation time of comparation of some kinds of sorting methods with ordered list (INPUT: ASCENDING LIST  => OUTPUT: ASCENDING LIST) ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('sort_orderedlist.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,1], c='k', marker='*', alpha=0.9, label='Bubble(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,2], c='r', marker='d', alpha=0.9, label='Shell(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,3], c='g', marker='s', alpha=0.9, label='Quick(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,4], c='b', marker='o', alpha=0.9, label='Heap(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,5], c='m', marker='<', alpha=0.9, label='Select(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,6], c='y', marker='v', alpha=0.9, label='Insert(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,7], c='c', marker='>', alpha=0.9, label=' SLinkedList_Merge(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,8], c='navy', marker='^', alpha=0.9, label='DLinkedList_Merge(ms)')
plt.scatter(Order_reverse_list[:, 0],  alisttime[:,9], c='deeppink', marker='+', alpha=0.9, label='XArrayList_Merge(ms)')

plt.legend()
plt.title('Computation time of comparation of some kinds of sorting methods with ordered list (INPUT: ASCENDING LIST  => OUTPUT: DESENDING LIST) ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('sort_orderedReverselist.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Random_list[:, 0],  Random_list[:,1], c='k', marker='*', alpha=0.9, label='Bubble(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,2], c='r', marker='d', alpha=0.9, label='Shell(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,3], c='g', marker='s', alpha=0.9, label='Quick(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,4], c='b', marker='o', alpha=0.9, label='Heap(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,5], c='m', marker='<', alpha=0.9, label='Select(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,6], c='y', marker='v', alpha=0.9, label='Insert(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,7], c='c', marker='>', alpha=0.9, label=' SLinkedList_Merge(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,8], c='navy', marker='^', alpha=0.9, label='DLinkedList_Merge(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,9], c='deeppink', marker='+', alpha=0.9, label='XArrayList_Merge(ms)')

plt.legend()
plt.title('Computation time of comparation of some kinds of sorting methods with ordered list (INPUT: RANDOM LIST  => OUTPUT: DESENDING LIST) ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('sort_randomlist.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,1], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,1], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,1], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of BUBBLE SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('Bubble_sort.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,2], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,2], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,2], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of SHELL SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('Shell_sort.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,3], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,3], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,3], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of QUICK SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('Quick_sort.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,4], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,4], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,4], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of HEAP SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('Heap_sort.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,5], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,5], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,5], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of SELECTION SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('selection_sort.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,6], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,6], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,6], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of INSERTION SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('Insertion_sort.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,7], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,7], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,7], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of MERGE_SLINKEDLIST SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('Merge_SLL_sort.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,8], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,8], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,8], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of MERGE_DLINKEDLIST SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('Merge_DLL_sort.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Order_list = pd.read_csv('sortOrdered.csv')
Order_list = Order_list.to_numpy()

Order_reverse_list = pd.read_csv('sortOrderedReverse.csv')
Order_reverse_list = Order_reverse_list.to_numpy()

Random_list = pd.read_csv('sortRandom.csv')
Random_list = Random_list.to_numpy()

fig = plt.figure(figsize=(15, 8))
plt.scatter(Order_list[:, 0],  Order_list[:,9], c='k', marker='*', alpha=0.9, label='Order List(ms)')
plt.scatter(Order_reverse_list[:, 0],  Order_reverse_list[:,9], c='r', marker='d', alpha=0.9, label='Ordered reverse list(ms)')
plt.scatter(Random_list[:, 0],  Random_list[:,9], c='g', marker='s', alpha=0.9, label='Random list(ms)')


plt.legend()
plt.title('Computation time of comparation of MERGE_XARRAYLIST SORTING methods with 3 kinds of list ')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
fig.savefig('Merge_XArray_sort.jpeg')
plt.show()
